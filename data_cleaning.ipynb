# %%
import pandas as pd
import numpy as np

# %%
url="data/WineQT.csv"
df=pd.read_csv(url)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
for col in df.columns:
    print(f'{col} mean: {np.mean(df[col].isnull())}')
# Out:
# fixed acidity mean: 0.0
# volatile acidity mean: 0.0
# citric acid mean: 0.0
# residual sugar mean: 0.0
# chlorides mean: 0.0
# free sulfur dioxide mean: 0.0
# total sulfur dioxide mean: 0.0
# density mean: 0.0
# pH mean: 0.0
# sulphates mean: 0.0
# alcohol mean: 0.0
# quality mean: 0.0
# Id mean: 0.0

# %%
df.dtypes
# Out:
# fixed acidity           object
# volatile acidity        object
# citric acid             object
# residual sugar          object
# chlorides               object
# free sulfur dioxide     object
# total sulfur dioxide    object
# density                 object
# pH                      object
# sulphates               object
# alcohol                 object
# quality                 object
# Id                      object
# dtype: object

# %%
df.loc[(df['citric acid']>.5) & (df['residual sugar']>2)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 39             10.2              0.42         0.57             3.4      0.070
# 51              8.8              0.41         0.64             2.2      0.093
# 103             9.2              0.52         1.00             3.4      0.610
# 145            12.8              0.30         0.74             2.6      0.095
# 146            12.8              0.30         0.74             2.6      0.095
# ...             ...               ...          ...             ...        ...
# 1073            7.5              0.38         0.57             2.3      0.106
# 1076            7.5              0.38         0.57             2.3      0.106
# 1077            7.1              0.27         0.60             2.1      0.074
# 1118            6.7              0.16         0.64             2.1      0.059
# 1122            6.4              0.36         0.53             2.2      0.230
#
# ...

# %%
for i, row in df.iterrows():
    if i==0:
        print('yes')
    if row['residual sugar']>2:
        df.loc[i,'residual sugar']=200
# Out:
# yes

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00           200.0      0.098
# 2               7.8             0.760         0.04           200.0      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13           200.0      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10           200.0      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.drop('fixed acidity',axis=1)
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 0                0.700         0.00             1.9      0.076
# 2                0.760         0.04             2.3      0.092
# 3                0.280         0.56             1.9      0.075
# 4                0.700         0.00             1.9      0.076
# 5                0.660         0.00             1.8      0.075
# ...                ...          ...             ...        ...
# 1138             0.510         0.13             2.3      0.076
# 1139             0.620         0.08             1.9      0.068
# 1140             0.600         0.08             2.0      0.090
# 1141             0.550         0.10             2.2      0.062
# 1142             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# ...

# %%
df2=df[['fixed acidity','residual sugar']]

# %%
df2=df[['fixed acidity']]

# %%
df2.rename(columns={'fixed acidity':'acidity'},inplace=True)
df2
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       acidity  residual sugar
# 0         7.4             1.9
# 1         7.8             2.6
# 2         7.8             2.3
# 3        11.2             1.9
# 4         7.4             1.9
# ...       ...             ...
# 1138      6.3             2.3
# 1139      6.8             1.9
# 1140      6.2             2.0
# 1141      5.9             2.2
# 1142      5.9             2.0
#
# [1143 rows x 2 columns]

# %%
df.groupby('quality').mean().sort_values('fixed acidity',ascending=False)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 7             8.851049          0.393671     0.386573        2.760140
# 8             8.806250          0.410000     0.432500        2.643750
# 3             8.450000          0.897500     0.211667        2.666667
# 6             8.317749          0.504957     0.263680        2.444805
# 5             8.161077          0.585280     0.240124        2.540476
# 4             7.809091          0.700000     0.165758        2.566667
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 7         0.075217            14.538462             37.489510  0.996071
# 8         0.070187            11.062500             29.375000  0.995553
# 3         0.105333             8.166667             24.500000  0.997682
# 6         0.085281            15.215368             39.941558  0.996610
# 5         0.091770            16.612836             55.299172  0.997073
# ...

# %%
del df['alcohol']
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df['quality']=df['quality'].replace({5:20})
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.sum(axis=1)
# Out:
# 0         89.54380
# 1        139.05480
# 2        116.69900
# 3        114.55300
# 4         93.54380
#            ...
# 1138    1692.48174
# 1139    1689.20451
# 1140    1714.49490
# 1141    1716.28712
# 1142    1717.21547
# Length: 1143, dtype: float64

# %%
df['quality'].value_counts()
# Out:
# 20    483
# 6     462
# 7     143
# 4      33
# 8      16
# 3       6
# Name: quality, dtype: int64

# %%
#reorder
df2=df[['fixed acidity','residual sugar']]


#rename columns
df2.rename(columns={'fixed acidity':'acidity'},inplace=True)


#loc
df.loc[(df['citric acid']>.5) & (df['residual sugar']>2)]


#dtype
df.dtypes
df['residual sugar'].astype(float)


#groupby
df.groupby('quality').mean()


#sort
df.sort_values('fixed acidity',ascending=False)


#delete nulls
for col in df.columns:
    print(f'{col} mean: {np.mean(df[col].isnull())}')


#count unique values
df['quality'].value_counts()

#delete column
del df['alcohol']
#or
df.drop('fixed acidity',axis=1)


#replace values
df['quality']=df['quality'].replace({'candy':'Candy'})


#sum rows
df.sum(axis=1)


#bins
bins=[0,9,11,15]
wine_label=['min','mid','max']
df['wine label']=pd.cut(df['alcohol'],bins,labels=wine_label,include_lowest=True)


#iterrows
for i, row in df.iterrows():

    
#change cell value
df.loc[i,'residual sugar']=200


#loc just show a few rows
df.loc[df['residual sugar']>3,['alcohol','quality']]

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id', 'residual_sugar'],
#       dtype='object')
